# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key

# %%
# Base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create set of random coordinates
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the coordinates to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create list for citites
cities = []

#Identify nearest city for coordinates
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If city is unique, add to list of cities
    if city not in cities: 
        cities.append(city)

#Print length of city list
len(cities)
# Out:
# 779

# %%
#Import datetime
from datetime import datetime

#Create empty list for weather data
city_data = []

#Print beginning of log
print("Beginning data retrieval")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through cities in list 
for i, city in enumerate(cities):
    #Group cities in sets of 50
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    #Create endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log URL, record, set num, city
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    record_count += 1
    
    #Run API req for each city
    try:
    #Parse JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]

        #Convert date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        #Append city info to city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current})
    
    #Skip errors
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate Data Loading complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval
# -----------------------------
# Processing record 1 of set 1 | assiniboia
# Processing record 2 of set 1 | vila velha
# Processing record 3 of set 1 | port blair
# Processing record 4 of set 1 | upernavik
# Processing record 5 of set 1 | manakara
# Processing record 6 of set 1 | ushuaia
# Processing record 7 of set 1 | souillac
# Processing record 8 of set 1 | bara
# Processing record 9 of set 1 | vanavara
# Processing record 10 of set 1 | sosnovo-ozerskoye
# Processing record 11 of set 1 | vokhma
# Processing record 12 of set 1 | noumea
# Processing record 13 of set 1 | albany
# Processing record 14 of set 1 | kodiak
# Processing record 15 of set 1 | kapaa
# Processing record 16 of set 1 | brandon
# Processing record 17 of set 1 | vaitupu
# City not found. Skipping...
# Processing record 18 of set 1 | naron
# Processing record 19 of set 1 | jining
# Processing record 20 of set 1 | annau
# Processing record 21 of set 1 | plettenberg bay
# Processing record 22 of set 1 | road town
# Processing record 23 of set 1 | leningradskiy
# Processing record 24 of set 1 | roald
# Processing record 25 of set 1 | gaoual
# Processing record 26 of set 1 | asau
# Processing record 27 of set 1 | tuktoyaktuk
# Processing record 28 of set 1 | agadir
# Processing record 29 of set 1 | cabo san lucas
# Processing record 30 of set 1 | rikitea
# Processing record 31 of set 1 | atar
# Processing record 32 of set 1 | tabiauea
# City not found. Skipping...
# Processing record 33 of set 1 | devils lake
# Processing record 34 of set 1 | port hedland
# Processing record 35 of set 1 | aklavik
# Processing record 36 of set 1 | faanui
# Processing record 37 of set 1 | fairbanks
# Processing record 38 of set 1 | esperance
# Processing record 39 of set 1 | faya
# Processing record 40 of set 1 | hilo
# Processing record 41 of set 1 | puerto palomas
# Processing record 42 of set 1 | taolanaro
# City not found. Skipping...
# Processing record 43 of set 1 | soyo
# Processing record 44 of set 1 | bambous virieux
# Processing record 45 of set 1 | beringovskiy
# Processing record 46 of set 1 | busselton
# Processing record 47 of set 1 | belushya guba
# City not found. Skipping...
# Processing record 48 of set 1 | adre
# Processing record 49 of set 1 | bluff
# Processing record 50 of set 1 | nouadhibou
# Processing record 1 of set 2 | vaini
# Processing record 2 of set 2 | atuona
# Processing record 3 of set 2 | goderich
# Processing record 4 of set 2 | bam
# Processing record 5 of set 2 | shenjiamen
# Processing record 6 of set 2 | kumluca
# Processing record 7 of set 2 | codrington
# Processing record 8 of set 2 | hukuntsi
# Processing record 9 of set 2 | svetlyy
# Processing record 10 of set 2 | mys shmidta
# City not found. Skipping...
# Processing record 11 of set 2 | clyde river
# Processing record 12 of set 2 | yomou
# Processing record 13 of set 2 | bababe
# City not found. Skipping...
# Processing record 14 of set 2 | marcona
# City not found. Skipping...
# Processing record 15 of set 2 | port elizabeth
# Processing record 16 of set 2 | chokurdakh
# Processing record 17 of set 2 | tucuman
# Processing record 18 of set 2 | camopi
# Processing record 19 of set 2 | tasiilaq
# Processing record 20 of set 2 | jalu
# Processing record 21 of set 2 | port lincoln
# Processing record 22 of set 2 | mon
# Processing record 23 of set 2 | huangzhai
# Processing record 24 of set 2 | bataipora
# Processing record 25 of set 2 | petushki
# Processing record 26 of set 2 | saint george
# Processing record 27 of set 2 | hermanus
# Processing record 28 of set 2 | kalabo
# Processing record 29 of set 2 | haines junction
# Processing record 30 of set 2 | tiksi
# Processing record 31 of set 2 | mataura
# Processing record 32 of set 2 | bulgan
# Processing record 33 of set 2 | adrar
# Processing record 34 of set 2 | kurchum
# Processing record 35 of set 2 | saint-augustin
# Processing record 36 of set 2 | nelson bay
# Processing record 37 of set 2 | taoudenni
# Processing record 38 of set 2 | maunabo
# Processing record 39 of set 2 | cairns
# Processing record 40 of set 2 | mogochin
# City not found. Skipping...
# Processing record 41 of set 2 | qaanaaq
# Processing record 42 of set 2 | barrow
# Processing record 43 of set 2 | mahebourg
# Processing record 44 of set 2 | punta arenas
# Processing record 45 of set 2 | norman wells
# Processing record 46 of set 2 | erenhot
# Processing record 47 of set 2 | vallenar
# Processing record 48 of set 2 | butaritari
# Processing record 49 of set 2 | hay river
# Processing record 50 of set 2 | mkushi
# Processing record 1 of set 3 | beloha
# Processing record 2 of set 3 | aykhal
# Processing record 3 of set 3 | fort nelson
# Processing record 4 of set 3 | baraboo
# Processing record 5 of set 3 | jamestown
# Processing record 6 of set 3 | malakal
# Processing record 7 of set 3 | launceston
# Processing record 8 of set 3 | fonte boa
# Processing record 9 of set 3 | dikson
# Processing record 10 of set 3 | laguna
# Processing record 11 of set 3 | cape town
# Processing record 12 of set 3 | touros
# Processing record 13 of set 3 | klaksvik
# Processing record 14 of set 3 | vera cruz
# Processing record 15 of set 3 | georgetown
# Processing record 16 of set 3 | novikovo
# Processing record 17 of set 3 | sedelnikovo
# City not found. Skipping...
# Processing record 18 of set 3 | gazanjyk
# Processing record 19 of set 3 | terra santa
# Processing record 20 of set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing record 21 of set 3 | isangel
# Processing record 22 of set 3 | bandarbeyla
# Processing record 23 of set 3 | rockhampton
# Processing record 24 of set 3 | samalaeulu
# City not found. Skipping...
# Processing record 25 of set 3 | carnarvon
# Processing record 26 of set 3 | santa cruz
# Processing record 27 of set 3 | maracaju
# Processing record 28 of set 3 | chirongui
# Processing record 29 of set 3 | bengkulu
# Processing record 30 of set 3 | port alfred
# Processing record 31 of set 3 | ilhabela
# Processing record 32 of set 3 | gbongan
# Processing record 33 of set 3 | krasnoselkup
# Processing record 34 of set 3 | isilkul
# Processing record 35 of set 3 | zaysan
# Processing record 36 of set 3 | rayadrug
# Processing record 37 of set 3 | namibe
# Processing record 38 of set 3 | east london
# Processing record 39 of set 3 | sistranda
# Processing record 40 of set 3 | mar del plata
# Processing record 41 of set 3 | labuhan
# Processing record 42 of set 3 | lebu
# Processing record 43 of set 3 | selma
# Processing record 44 of set 3 | avera
# Processing record 45 of set 3 | fortuna
# Processing record 46 of set 3 | kaduqli
# Processing record 47 of set 3 | podor
# Processing record 48 of set 3 | caraquet
# Processing record 49 of set 3 | half moon bay
# Processing record 50 of set 3 | tura
# Processing record 1 of set 4 | pangnirtung
# Processing record 2 of set 4 | chapais
# Processing record 3 of set 4 | morant bay
# Processing record 4 of set 4 | padang
# Processing record 5 of set 4 | bredasdorp
# Processing record 6 of set 4 | wamba
# Processing record 7 of set 4 | fuerte olimpo
# Processing record 8 of set 4 | boffa
# Processing record 9 of set 4 | paradwip
# City not found. Skipping...
# Processing record 10 of set 4 | khatanga
# Processing record 11 of set 4 | ribeira grande
# Processing record 12 of set 4 | ponta do sol
# Processing record 13 of set 4 | douglas
# Processing record 14 of set 4 | la tuque
# Processing record 15 of set 4 | hailin
# Processing record 16 of set 4 | longyearbyen
# Processing record 17 of set 4 | elko
# Processing record 18 of set 4 | narsaq
# Processing record 19 of set 4 | bandar-e torkaman
# City not found. Skipping...
# Processing record 20 of set 4 | tarko-sale
# Processing record 21 of set 4 | hofn
# Processing record 22 of set 4 | port keats
# Processing record 23 of set 4 | ancud
# Processing record 24 of set 4 | tigzirt
# Processing record 25 of set 4 | nichinan
# Processing record 26 of set 4 | castro
# Processing record 27 of set 4 | onufriyivka
# Processing record 28 of set 4 | puerto ayora
# Processing record 29 of set 4 | lavrentiya
# Processing record 30 of set 4 | sambava
# Processing record 31 of set 4 | arraial do cabo
# Processing record 32 of set 4 | port-gentil
# Processing record 33 of set 4 | nikolskoye
# Processing record 34 of set 4 | seia
# Processing record 35 of set 4 | sao felix do xingu
# Processing record 36 of set 4 | cayenne
# Processing record 37 of set 4 | luderitz
# Processing record 38 of set 4 | paramonga
# Processing record 39 of set 4 | ahipara
# Processing record 40 of set 4 | ternate
# Processing record 41 of set 4 | saint-philippe
# Processing record 42 of set 4 | tsihombe
# City not found. Skipping...
# Processing record 43 of set 4 | taseyevo
# Processing record 44 of set 4 | broken hill
# Processing record 45 of set 4 | nizwa
# Processing record 46 of set 4 | vila franca do campo
# Processing record 47 of set 4 | conakry
# Processing record 48 of set 4 | tibu
# Processing record 49 of set 4 | kavieng
# Processing record 50 of set 4 | ostrovnoy
# Processing record 1 of set 5 | kaitangata
# Processing record 2 of set 5 | matara
# Processing record 3 of set 5 | tuatapere
# Processing record 4 of set 5 | goba
# Processing record 5 of set 5 | iqaluit
# Processing record 6 of set 5 | novaya igirma
# Processing record 7 of set 5 | yellowknife
# Processing record 8 of set 5 | kawana waters
# City not found. Skipping...
# Processing record 9 of set 5 | severo-kurilsk
# Processing record 10 of set 5 | alofi
# Processing record 11 of set 5 | san cristobal
# Processing record 12 of set 5 | hereford
# Processing record 13 of set 5 | skjervoy
# Processing record 14 of set 5 | mujiayingzi
# Processing record 15 of set 5 | lagoa
# Processing record 16 of set 5 | zabaykalsk
# Processing record 17 of set 5 | bajo baudo
# City not found. Skipping...
# Processing record 18 of set 5 | koundara
# Processing record 19 of set 5 | tsukumi
# Processing record 20 of set 5 | attawapiskat
# City not found. Skipping...
# Processing record 21 of set 5 | khairabad
# Processing record 22 of set 5 | dourados
# Processing record 23 of set 5 | thinadhoo
# Processing record 24 of set 5 | rocha
# Processing record 25 of set 5 | chuy
# Processing record 26 of set 5 | batagay-alyta
# Processing record 27 of set 5 | kattivakkam
# Processing record 28 of set 5 | bolgatanga
# Processing record 29 of set 5 | brae
# Processing record 30 of set 5 | inirida
# Processing record 31 of set 5 | algiers
# Processing record 32 of set 5 | kilmez
# City not found. Skipping...
# Processing record 33 of set 5 | saskylakh
# Processing record 34 of set 5 | sentyabrskiy
# City not found. Skipping...
# Processing record 35 of set 5 | temaraia
# City not found. Skipping...
# Processing record 36 of set 5 | pozarevac
# Processing record 37 of set 5 | malpe
# Processing record 38 of set 5 | nouakchott
# Processing record 39 of set 5 | hobart
# Processing record 40 of set 5 | obigarm
# Processing record 41 of set 5 | berdyaush
# Processing record 42 of set 5 | jumla
# Processing record 43 of set 5 | robertsport
# Processing record 44 of set 5 | sur
# Processing record 45 of set 5 | glasgow
# Processing record 46 of set 5 | gejiu
# Processing record 47 of set 5 | mocambique
# City not found. Skipping...
# Processing record 48 of set 5 | airai
# Processing record 49 of set 5 | san patricio
# Processing record 50 of set 5 | bud
# Processing record 1 of set 6 | kazalinsk
# City not found. Skipping...
# Processing record 2 of set 6 | egvekinot
# Processing record 3 of set 6 | the valley
# Processing record 4 of set 6 | ponot
# Processing record 5 of set 6 | rovaniemi
# Processing record 6 of set 6 | whitehorse
# Processing record 7 of set 6 | ekimchan
# Processing record 8 of set 6 | nacala
# Processing record 9 of set 6 | quatre cocos
# Processing record 10 of set 6 | upata
# Processing record 11 of set 6 | jaisalmer
# Processing record 12 of set 6 | bubaque
# Processing record 13 of set 6 | wulanhaote
# City not found. Skipping...
# Processing record 14 of set 6 | saleaula
# City not found. Skipping...
# Processing record 15 of set 6 | opelousas
# Processing record 16 of set 6 | ornes
# Processing record 17 of set 6 | jaslo
# Processing record 18 of set 6 | dalbandin
# Processing record 19 of set 6 | kafanchan
# Processing record 20 of set 6 | celestun
# Processing record 21 of set 6 | taian
# Processing record 22 of set 6 | pumiao
# Processing record 23 of set 6 | karaul
# City not found. Skipping...
# Processing record 24 of set 6 | merauke
# Processing record 25 of set 6 | black river
# Processing record 26 of set 6 | pangkalanbuun
# Processing record 27 of set 6 | kisangani
# Processing record 28 of set 6 | flinders
# Processing record 29 of set 6 | cap malheureux
# Processing record 30 of set 6 | henties bay
# Processing record 31 of set 6 | areia branca
# Processing record 32 of set 6 | sibolga
# Processing record 33 of set 6 | opuwo
# Processing record 34 of set 6 | la palma
# Processing record 35 of set 6 | bethel
# Processing record 36 of set 6 | namatanai
# Processing record 37 of set 6 | burnie
# Processing record 38 of set 6 | chagda
# City not found. Skipping...
# Processing record 39 of set 6 | guerrero negro
# Processing record 40 of set 6 | pochutla
# Processing record 41 of set 6 | cleveland
# Processing record 42 of set 6 | poum
# Processing record 43 of set 6 | sinnamary
# Processing record 44 of set 6 | lodja
# Processing record 45 of set 6 | juventino rosas
# Processing record 46 of set 6 | phan thiet
# Processing record 47 of set 6 | sataua
# City not found. Skipping...
# Processing record 48 of set 6 | strathpeffer
# Processing record 49 of set 6 | mount gambier
# Processing record 50 of set 6 | husavik
# Processing record 1 of set 7 | te anau
# Processing record 2 of set 7 | shingu
# Processing record 3 of set 7 | roznava
# Processing record 4 of set 7 | erzincan
# Processing record 5 of set 7 | kiruna
# Processing record 6 of set 7 | carlyle
# Processing record 7 of set 7 | katsuura
# Processing record 8 of set 7 | monchegorsk
# Processing record 9 of set 7 | barra patuca
# Processing record 10 of set 7 | salo
# Processing record 11 of set 7 | las tunas
# Processing record 12 of set 7 | kotra
# Processing record 13 of set 7 | derzhavinsk
# Processing record 14 of set 7 | inderborskiy
# City not found. Skipping...
# Processing record 15 of set 7 | deputatskiy
# Processing record 16 of set 7 | san lorenzo
# Processing record 17 of set 7 | constantine
# Processing record 18 of set 7 | tual
# Processing record 19 of set 7 | pokhara
# Processing record 20 of set 7 | ilheus
# Processing record 21 of set 7 | amderma
# City not found. Skipping...
# Processing record 22 of set 7 | aswan
# Processing record 23 of set 7 | peterborough
# Processing record 24 of set 7 | hirara
# Processing record 25 of set 7 | thompson
# Processing record 26 of set 7 | hambantota
# Processing record 27 of set 7 | grindavik
# Processing record 28 of set 7 | santa maria
# Processing record 29 of set 7 | new norfolk
# Processing record 30 of set 7 | avarua
# Processing record 31 of set 7 | kokoda
# Processing record 32 of set 7 | koindu
# Processing record 33 of set 7 | kahului
# Processing record 34 of set 7 | palmer
# Processing record 35 of set 7 | cherskiy
# Processing record 36 of set 7 | ilulissat
# Processing record 37 of set 7 | vestmannaeyjar
# Processing record 38 of set 7 | bilma
# Processing record 39 of set 7 | pevek
# Processing record 40 of set 7 | sitka
# Processing record 41 of set 7 | norrtalje
# Processing record 42 of set 7 | mayskiy
# Processing record 43 of set 7 | jaffna
# Processing record 44 of set 7 | sacama
# Processing record 45 of set 7 | pisco
# Processing record 46 of set 7 | pavlikeni
# Processing record 47 of set 7 | merritt
# Processing record 48 of set 7 | bilibino
# Processing record 49 of set 7 | almeirim
# Processing record 50 of set 7 | aksha
# Processing record 1 of set 8 | port hardy
# Processing record 2 of set 8 | wanning
# Processing record 3 of set 8 | evensk
# Processing record 4 of set 8 | grand river south east
# City not found. Skipping...
# Processing record 5 of set 8 | monrovia
# Processing record 6 of set 8 | constitucion
# Processing record 7 of set 8 | kalmunai
# Processing record 8 of set 8 | moranbah
# Processing record 9 of set 8 | verkhoyansk
# Processing record 10 of set 8 | neuquen
# Processing record 11 of set 8 | gusinoye ozero
# Processing record 12 of set 8 | gravelbourg
# Processing record 13 of set 8 | lemesos
# City not found. Skipping...
# Processing record 14 of set 8 | abu dhabi
# Processing record 15 of set 8 | puerto escondido
# Processing record 16 of set 8 | keti bandar
# Processing record 17 of set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing record 18 of set 8 | saint-joseph
# Processing record 19 of set 8 | tessalit
# Processing record 20 of set 8 | reshetylivka
# Processing record 21 of set 8 | kavaratti
# Processing record 22 of set 8 | taltal
# Processing record 23 of set 8 | nishihara
# Processing record 24 of set 8 | luganville
# Processing record 25 of set 8 | lompoc
# Processing record 26 of set 8 | sakakah
# Processing record 27 of set 8 | kanbe
# Processing record 28 of set 8 | riyadh
# Processing record 29 of set 8 | nizhneyansk
# City not found. Skipping...
# Processing record 30 of set 8 | baghdad
# Processing record 31 of set 8 | moyale
# Processing record 32 of set 8 | batobato
# Processing record 33 of set 8 | tsumeb
# Processing record 34 of set 8 | kloulklubed
# Processing record 35 of set 8 | samusu
# City not found. Skipping...
# Processing record 36 of set 8 | muyezerskiy
# Processing record 37 of set 8 | turtkul
# City not found. Skipping...
# Processing record 38 of set 8 | huanren
# Processing record 39 of set 8 | abashiri
# Processing record 40 of set 8 | evinayong
# Processing record 41 of set 8 | lima
# Processing record 42 of set 8 | tomatlan
# Processing record 43 of set 8 | craigieburn
# Processing record 44 of set 8 | virden
# Processing record 45 of set 8 | broadford
# Processing record 46 of set 8 | jaen
# Processing record 47 of set 8 | loukhi
# Processing record 48 of set 8 | viedma
# Processing record 49 of set 8 | olafsvik
# Processing record 50 of set 8 | oistins
# Processing record 1 of set 9 | ereymentau
# Processing record 2 of set 9 | saint anthony
# Processing record 3 of set 9 | los llanos de aridane
# Processing record 4 of set 9 | zhanatas
# City not found. Skipping...
# Processing record 5 of set 9 | shakawe
# Processing record 6 of set 9 | santa rita do sapucai
# Processing record 7 of set 9 | raga
# Processing record 8 of set 9 | grand centre
# City not found. Skipping...
# Processing record 9 of set 9 | huoqiu
# Processing record 10 of set 9 | nhulunbuy
# Processing record 11 of set 9 | palabuhanratu
# City not found. Skipping...
# Processing record 12 of set 9 | arandis
# Processing record 13 of set 9 | mandalgovi
# Processing record 14 of set 9 | doha
# Processing record 15 of set 9 | certeze
# Processing record 16 of set 9 | teya
# Processing record 17 of set 9 | samana
# Processing record 18 of set 9 | traipu
# Processing record 19 of set 9 | zabol
# Processing record 20 of set 9 | carlogani
# Processing record 21 of set 9 | marawi
# Processing record 22 of set 9 | hope
# Processing record 23 of set 9 | srednekolymsk
# Processing record 24 of set 9 | urdoma
# Processing record 25 of set 9 | prieska
# Processing record 26 of set 9 | kegayli
# City not found. Skipping...
# Processing record 27 of set 9 | vestmanna
# Processing record 28 of set 9 | boralday
# Processing record 29 of set 9 | makakilo city
# Processing record 30 of set 9 | klyuchi
# Processing record 31 of set 9 | talnakh
# Processing record 32 of set 9 | alice springs
# Processing record 33 of set 9 | hailey
# Processing record 34 of set 9 | ust-omchug
# Processing record 35 of set 9 | alta floresta
# Processing record 36 of set 9 | saint-raymond
# Processing record 37 of set 9 | almaty
# Processing record 38 of set 9 | sicuani
# Processing record 39 of set 9 | suao
# City not found. Skipping...
# Processing record 40 of set 9 | san juan
# Processing record 41 of set 9 | lorengau
# Processing record 42 of set 9 | puerto maldonado
# Processing record 43 of set 9 | hede
# Processing record 44 of set 9 | yining
# Processing record 45 of set 9 | coihaique
# Processing record 46 of set 9 | salalah
# Processing record 47 of set 9 | morehead
# Processing record 48 of set 9 | bonavista
# Processing record 49 of set 9 | ust-kuyga
# Processing record 50 of set 9 | portland
# Processing record 1 of set 10 | benalla
# Processing record 2 of set 10 | pangai
# Processing record 3 of set 10 | linqiong
# Processing record 4 of set 10 | port macquarie
# Processing record 5 of set 10 | gorontalo
# Processing record 6 of set 10 | pitimbu
# Processing record 7 of set 10 | buqayq
# City not found. Skipping...
# Processing record 8 of set 10 | weatherford
# Processing record 9 of set 10 | penzance
# Processing record 10 of set 10 | provideniya
# Processing record 11 of set 10 | at-bashi
# Processing record 12 of set 10 | rawson
# Processing record 13 of set 10 | loa janan
# Processing record 14 of set 10 | bundaberg
# Processing record 15 of set 10 | puerto rico
# Processing record 16 of set 10 | darhan
# Processing record 17 of set 10 | gondanglegi
# Processing record 18 of set 10 | katherine
# Processing record 19 of set 10 | bunia
# Processing record 20 of set 10 | petropavl
# Processing record 21 of set 10 | ola
# Processing record 22 of set 10 | halifax
# Processing record 23 of set 10 | ijaki
# City not found. Skipping...
# Processing record 24 of set 10 | khani
# Processing record 25 of set 10 | artyk
# City not found. Skipping...
# Processing record 26 of set 10 | tabou
# Processing record 27 of set 10 | santa cruz del sur
# Processing record 28 of set 10 | puerto baquerizo moreno
# Processing record 29 of set 10 | ulladulla
# Processing record 30 of set 10 | tamandare
# Processing record 31 of set 10 | los andes
# Processing record 32 of set 10 | jiddah
# City not found. Skipping...
# Processing record 33 of set 10 | vao
# Processing record 34 of set 10 | bathsheba
# Processing record 35 of set 10 | dunedin
# Processing record 36 of set 10 | ballina
# Processing record 37 of set 10 | saldanha
# Processing record 38 of set 10 | chara
# Processing record 39 of set 10 | chico
# Processing record 40 of set 10 | walvis bay
# Processing record 41 of set 10 | praia
# Processing record 42 of set 10 | marrakesh
# Processing record 43 of set 10 | sohag
# Processing record 44 of set 10 | anicuns
# Processing record 45 of set 10 | la rioja
# Processing record 46 of set 10 | kracheh
# City not found. Skipping...
# Processing record 47 of set 10 | vilhena
# Processing record 48 of set 10 | sidi ali
# Processing record 49 of set 10 | khalkhal
# Processing record 50 of set 10 | oranjemund
# Processing record 1 of set 11 | miri
# Processing record 2 of set 11 | omboue
# Processing record 3 of set 11 | cidreira
# Processing record 4 of set 11 | barentsburg
# City not found. Skipping...
# Processing record 5 of set 11 | samarai
# Processing record 6 of set 11 | yangjiang
# Processing record 7 of set 11 | dipkarpaz
# City not found. Skipping...
# Processing record 8 of set 11 | kintampo
# Processing record 9 of set 11 | torbay
# Processing record 10 of set 11 | rutland
# Processing record 11 of set 11 | tokur
# Processing record 12 of set 11 | nantucket
# Processing record 13 of set 11 | urucara
# Processing record 14 of set 11 | havoysund
# Processing record 15 of set 11 | victoria point
# Processing record 16 of set 11 | mawlaik
# Processing record 17 of set 11 | trapani
# Processing record 18 of set 11 | talaya
# Processing record 19 of set 11 | guilin
# Processing record 20 of set 11 | ziro
# Processing record 21 of set 11 | hasaki
# Processing record 22 of set 11 | abalak
# Processing record 23 of set 11 | oranjestad
# Processing record 24 of set 11 | vardo
# Processing record 25 of set 11 | moa
# Processing record 26 of set 11 | hamilton
# Processing record 27 of set 11 | palmira
# Processing record 28 of set 11 | gayny
# Processing record 29 of set 11 | chany
# Processing record 30 of set 11 | najran
# Processing record 31 of set 11 | daru
# Processing record 32 of set 11 | wajima
# Processing record 33 of set 11 | mount isa
# Processing record 34 of set 11 | baykit
# Processing record 35 of set 11 | westport
# Processing record 36 of set 11 | hithadhoo
# Processing record 37 of set 11 | isla vista
# Processing record 38 of set 11 | beaverlodge
# Processing record 39 of set 11 | trelleborg
# Processing record 40 of set 11 | severo-yeniseyskiy
# Processing record 41 of set 11 | tateyama
# Processing record 42 of set 11 | lakes entrance
# Processing record 43 of set 11 | buchanan
# Processing record 44 of set 11 | dolinsk
# Processing record 45 of set 11 | suraabad
# Processing record 46 of set 11 | myanaung
# Processing record 47 of set 11 | fare
# Processing record 48 of set 11 | ankang
# Processing record 49 of set 11 | xai-xai
# Processing record 50 of set 11 | sao filipe
# Processing record 1 of set 12 | turukhansk
# Processing record 2 of set 12 | saint-pierre
# Processing record 3 of set 12 | yatou
# Processing record 4 of set 12 | awbari
# Processing record 5 of set 12 | makurdi
# Processing record 6 of set 12 | weligama
# Processing record 7 of set 12 | scarborough
# Processing record 8 of set 12 | newport
# Processing record 9 of set 12 | ust-maya
# Processing record 10 of set 12 | rio de janeiro
# Processing record 11 of set 12 | ixtapa
# Processing record 12 of set 12 | igrim
# Processing record 13 of set 12 | hailar
# Processing record 14 of set 12 | homer
# Processing record 15 of set 12 | santa barbara
# Processing record 16 of set 12 | kandrian
# Processing record 17 of set 12 | karauzyak
# City not found. Skipping...
# Processing record 18 of set 12 | dinguiraye
# Processing record 19 of set 12 | nueva loja
# Processing record 20 of set 12 | iquique
# Processing record 21 of set 12 | takoradi
# Processing record 22 of set 12 | yerbogachen
# Processing record 23 of set 12 | san jose
# Processing record 24 of set 12 | cacu
# Processing record 25 of set 12 | tetiyiv
# Processing record 26 of set 12 | fort saint john
# City not found. Skipping...
# Processing record 27 of set 12 | maltahohe
# Processing record 28 of set 12 | kecel
# Processing record 29 of set 12 | abha
# Processing record 30 of set 12 | mezen
# Processing record 31 of set 12 | cockburn town
# Processing record 32 of set 12 | umkomaas
# Processing record 33 of set 12 | caluquembe
# Processing record 34 of set 12 | fort collins
# Processing record 35 of set 12 | karratha
# Processing record 36 of set 12 | alamosa
# Processing record 37 of set 12 | manoel urbano
# Processing record 38 of set 12 | komsomolskiy
# Processing record 39 of set 12 | magistralnyy
# Processing record 40 of set 12 | beloslav
# Processing record 41 of set 12 | coquimbo
# Processing record 42 of set 12 | inzhavino
# Processing record 43 of set 12 | montauban
# Processing record 44 of set 12 | sayyan
# Processing record 45 of set 12 | nuuk
# Processing record 46 of set 12 | indianola
# Processing record 47 of set 12 | knysna
# Processing record 48 of set 12 | harper
# Processing record 49 of set 12 | west wendover
# Processing record 50 of set 12 | gunjur
# Processing record 1 of set 13 | ketchikan
# Processing record 2 of set 13 | matagami
# Processing record 3 of set 13 | bujaru
# Processing record 4 of set 13 | corner brook
# Processing record 5 of set 13 | pozo colorado
# Processing record 6 of set 13 | piacabucu
# Processing record 7 of set 13 | yumen
# Processing record 8 of set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing record 9 of set 13 | kaniama
# Processing record 10 of set 13 | victoria
# Processing record 11 of set 13 | mponela
# Processing record 12 of set 13 | linxia
# Processing record 13 of set 13 | porvoo
# Processing record 14 of set 13 | crawfordsville
# Processing record 15 of set 13 | safaga
# Processing record 16 of set 13 | lluta
# Processing record 17 of set 13 | northam
# Processing record 18 of set 13 | pali
# Processing record 19 of set 13 | quelimane
# Processing record 20 of set 13 | college
# Processing record 21 of set 13 | mizdah
# Processing record 22 of set 13 | waitara
# Processing record 23 of set 13 | lensk
# Processing record 24 of set 13 | namwala
# Processing record 25 of set 13 | iznoski
# Processing record 26 of set 13 | muros
# Processing record 27 of set 13 | altus
# Processing record 28 of set 13 | nushki
# Processing record 29 of set 13 | dryden
# Processing record 30 of set 13 | dalvik
# Processing record 31 of set 13 | belaya gora
# Processing record 32 of set 13 | sao joao da barra
# Processing record 33 of set 13 | barawe
# City not found. Skipping...
# Processing record 34 of set 13 | karaton
# Processing record 35 of set 13 | naze
# Processing record 36 of set 13 | caravelas
# Processing record 37 of set 13 | malabugas
# Processing record 38 of set 13 | sao miguel
# Processing record 39 of set 13 | malwan
# City not found. Skipping...
# Processing record 40 of set 13 | kralendijk
# Processing record 41 of set 13 | nanortalik
# Processing record 42 of set 13 | catemaco
# Processing record 43 of set 13 | boma
# Processing record 44 of set 13 | hearst
# Processing record 45 of set 13 | hami
# Processing record 46 of set 13 | yulara
# Processing record 47 of set 13 | ialibu
# Processing record 48 of set 13 | azoyu
# Processing record 49 of set 13 | varzea grande
# Processing record 50 of set 13 | grand gaube
# Processing record 1 of set 14 | slave lake
# Processing record 2 of set 14 | lozuvatka
# Processing record 3 of set 14 | huarmey
# Processing record 4 of set 14 | belpasso
# Processing record 5 of set 14 | lubumbashi
# Processing record 6 of set 14 | kadaya
# Processing record 7 of set 14 | farrukhabad
# Processing record 8 of set 14 | sioux lookout
# Processing record 9 of set 14 | tiarei
# Processing record 10 of set 14 | linhares
# Processing record 11 of set 14 | san rafael
# Processing record 12 of set 14 | bakersfield
# Processing record 13 of set 14 | pastavy
# Processing record 14 of set 14 | inyonga
# Processing record 15 of set 14 | daxian
# City not found. Skipping...
# Processing record 16 of set 14 | amiens
# Processing record 17 of set 14 | tucuru
# Processing record 18 of set 14 | ankazobe
# Processing record 19 of set 14 | fereydun kenar
# Processing record 20 of set 14 | bayanday
# Processing record 21 of set 14 | saravena
# Processing record 22 of set 14 | kyzyl-mazhalyk
# Processing record 23 of set 14 | saint-leu
# Processing record 24 of set 14 | zolotinka
# City not found. Skipping...
# Processing record 25 of set 14 | staicele
# Processing record 26 of set 14 | geraldton
# Processing record 27 of set 14 | shimoda
# Processing record 28 of set 14 | greenville
# Processing record 29 of set 14 | bongandanga
# Processing record 30 of set 14 | makinsk
# Processing record 31 of set 14 | lithakia
# Processing record 32 of set 14 | orcopampa
# Processing record 33 of set 14 | paris
# Processing record 34 of set 14 | nemuro
# Processing record 35 of set 14 | izumo
# Processing record 36 of set 14 | peniche
# Processing record 37 of set 14 | ivanivka
# Processing record 38 of set 14 | tromso
# Processing record 39 of set 14 | mrirt
# City not found. Skipping...
# Processing record 40 of set 14 | kovdor
# Processing record 41 of set 14 | la crosse
# Processing record 42 of set 14 | san luis
# Processing record 43 of set 14 | winnemucca
# Processing record 44 of set 14 | bakchar
# Processing record 45 of set 14 | tawzar
# City not found. Skipping...
# Processing record 46 of set 14 | puerto leguizamo
# Processing record 47 of set 14 | yebaishou
# Processing record 48 of set 14 | bafoussam
# Processing record 49 of set 14 | suntar
# Processing record 50 of set 14 | sosnovka
# Processing record 1 of set 15 | uchkent
# Processing record 2 of set 15 | bachaquero
# Processing record 3 of set 15 | batemans bay
# Processing record 4 of set 15 | kangaatsiaq
# Processing record 5 of set 15 | kropotkin
# Processing record 6 of set 15 | balimo
# City not found. Skipping...
# Processing record 7 of set 15 | san quintin
# Processing record 8 of set 15 | mattru
# Processing record 9 of set 15 | skelleftea
# Processing record 10 of set 15 | vazhiny
# Processing record 11 of set 15 | nchelenge
# Processing record 12 of set 15 | kodinsk
# Processing record 13 of set 15 | lagos
# Processing record 14 of set 15 | broome
# Processing record 15 of set 15 | lincoln
# Processing record 16 of set 15 | diego de almagro
# Processing record 17 of set 15 | esfahan
# Processing record 18 of set 15 | gamboma
# Processing record 19 of set 15 | tonantins
# Processing record 20 of set 15 | itapaci
# Processing record 21 of set 15 | lianran
# Processing record 22 of set 15 | vyazma
# Processing record 23 of set 15 | trairi
# Processing record 24 of set 15 | tilichiki
# Processing record 25 of set 15 | calape
# Processing record 26 of set 15 | meyungs
# City not found. Skipping...
# Processing record 27 of set 15 | storforshei
# Processing record 28 of set 15 | tadine
# Processing record 29 of set 15 | sitio novo do tocantins
# Processing record 30 of set 15 | dingle
# Processing record 31 of set 15 | martil
# Processing record 32 of set 15 | obo
# Processing record 33 of set 15 | christchurch
# Processing record 34 of set 15 | casa nova
# Processing record 35 of set 15 | brigantine
# Processing record 36 of set 15 | oxapampa
# Processing record 37 of set 15 | mosquera
# Processing record 38 of set 15 | nampula
# Processing record 39 of set 15 | rosario
# Processing record 40 of set 15 | tumannyy
# City not found. Skipping...
# Processing record 41 of set 15 | dolbeau
# City not found. Skipping...
# Processing record 42 of set 15 | aksu
# Processing record 43 of set 15 | san ignacio
# Processing record 44 of set 15 | pong
# Processing record 45 of set 15 | chicama
# Processing record 46 of set 15 | beni mazar
# Processing record 47 of set 15 | comodoro rivadavia
# Processing record 48 of set 15 | sampit
# Processing record 49 of set 15 | buribay
# Processing record 50 of set 15 | pampierstad
# Processing record 1 of set 16 | enshi
# Processing record 2 of set 16 | sisimiut
# Processing record 3 of set 16 | pasuruan
# Processing record 4 of set 16 | safaqis
# City not found. Skipping...
# Processing record 5 of set 16 | sept-iles
# Processing record 6 of set 16 | abu zabad
# Processing record 7 of set 16 | negombo
# Processing record 8 of set 16 | myitkyina
# Processing record 9 of set 16 | grenville
# Processing record 10 of set 16 | vostok
# Processing record 11 of set 16 | ojinaga
# Processing record 12 of set 16 | barcea
# Processing record 13 of set 16 | olonets
# Processing record 14 of set 16 | zhicheng
# Processing record 15 of set 16 | yokadouma
# Processing record 16 of set 16 | tottori
# Processing record 17 of set 16 | chimore
# Processing record 18 of set 16 | weiden
# Processing record 19 of set 16 | praia da vitoria
# Processing record 20 of set 16 | tevriz
# Processing record 21 of set 16 | qaqortoq
# Processing record 22 of set 16 | trebisacce
# Processing record 23 of set 16 | cordoba
# Processing record 24 of set 16 | nalut
# Processing record 25 of set 16 | alihe
# Processing record 26 of set 16 | zalegoshch
# Processing record 27 of set 16 | kandi
# Processing record 28 of set 16 | mutata
# Processing record 29 of set 16 | tsabong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 718

# %%
#Convert l-d to pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Assiniboia  49.6334 -105.9845     78.71        14         100
# 1         Vila Velha -20.3297  -40.2925     78.75        85           0
# 2         Port Blair  11.6667   92.7500     82.00        81           8
# 3          Upernavik  72.7868  -56.1549     31.30        90         100
# 4           Manakara -22.1333   48.0167     69.66        93          34
# 5            Ushuaia -54.8000  -68.3000     31.66        93          40
# 6           Souillac -20.5167   57.5167     71.98        83          40
# 7               Bara  10.3744   10.7288     80.78        55          94
# 8           Vanavara  60.3400  102.2797     44.35        77          10
# 9  Sosnovo-Ozerskoye  52.5249  111.5418     34.48        67          99
#
#    Wind Speed Country                 Date Current Description
# 0       14.72      CA  2021-05-31 20:54:34     overcast clouds
# 1        5.01      BR  2021-05-31 20:54:13           clear sky
# 2        4.81      IN  2021-05-31 20:55:18           clear sky
# 3        3.04      GL  2021-05-31 20:47:47     overcast clouds
# 4        6.80      MG  2021-05-31 20:55:19          light rain
# 5        0.00      AR  2021-05-31 20:50:51    scattered clouds
# 6        8.52      MU  2021-05-31 20:50:57    scattered clouds
# 7       12.77      NG  2021-05-31 20:51:48     overcast clouds
# 8        4.00      RU  2021-05-31 20:46:37           clear sky
# 9        9.53      RU  2021-05-31 20:55:20     overcast clouds

# %%
#Reorder cols
new_col_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0         Assiniboia      CA  2021-05-31 20:54:34  49.6334 -105.9845
# 1         Vila Velha      BR  2021-05-31 20:54:13 -20.3297  -40.2925
# 2         Port Blair      IN  2021-05-31 20:55:18  11.6667   92.7500
# 3          Upernavik      GL  2021-05-31 20:47:47  72.7868  -56.1549
# 4           Manakara      MG  2021-05-31 20:55:19 -22.1333   48.0167
# 5            Ushuaia      AR  2021-05-31 20:50:51 -54.8000  -68.3000
# 6           Souillac      MU  2021-05-31 20:50:57 -20.5167   57.5167
# 7               Bara      NG  2021-05-31 20:51:48  10.3744   10.7288
# 8           Vanavara      RU  2021-05-31 20:46:37  60.3400  102.2797
# 9  Sosnovo-Ozerskoye      RU  2021-05-31 20:55:20  52.5249  111.5418
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     78.71        14         100       14.72     overcast clouds
# 1     78.75        85           0        5.01           clear sky
# 2     82.00        81           8        4.81           clear sky
# 3     31.30        90         100        3.04     overcast clouds
# 4     69.66        93          34        6.80          light rain
# 5     31.66        93          40        0.00    scattered clouds
# 6     71.98        83          40        8.52    scattered clouds
# 7     80.78        55          94       12.77     overcast clouds
# 8     44.35        77          10        4.00           clear sky
# 9     34.48        67          99        9.53     overcast clouds

# %%
#Create output file path
output_path = "Weather_Database/WeatherPy_Database.csv"

#Export city_data
city_data_df.to_csv(output_path, index_label = "City_ID")
