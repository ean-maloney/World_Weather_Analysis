# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key

# %%
# Base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create set of random coordinates
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the coordinates to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create list for citites
cities = []

#Identify nearest city for coordinates
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If city is unique, add to list of cities
    if city not in cities: 
        cities.append(city)

#Print length of city list
len(cities)
# Out:
# 604

# %%
#Import datetime
from datetime import datetime

#Create empty list for weather data
city_data = []

#Print beginning of log
print("Beginning data retrieval")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through cities in list 
for i, city in enumerate(cities):
    #Group cities in sets of 50
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    #Create endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log URL, record, set num, city
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    record_count += 1
    
    #Run API req for each city
    try:
    #Parse JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        #Convert date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        #Append city info to city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    #Skip errors
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate Data Loading complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval
# -----------------------------
# Processing record 1 of set 1 | longyearbyen
# Processing record 2 of set 1 | ushuaia
# Processing record 3 of set 1 | arraial do cabo
# Processing record 4 of set 1 | ksenyevka
# City not found. Skipping...
# Processing record 5 of set 1 | burica
# City not found. Skipping...
# Processing record 6 of set 1 | hermanus
# Processing record 7 of set 1 | kaitangata
# Processing record 8 of set 1 | rikitea
# Processing record 9 of set 1 | zephyrhills
# Processing record 10 of set 1 | kamina
# Processing record 11 of set 1 | nanortalik
# Processing record 12 of set 1 | nantucket
# Processing record 13 of set 1 | mataura
# Processing record 14 of set 1 | punta arenas
# Processing record 15 of set 1 | albany
# Processing record 16 of set 1 | seydi
# Processing record 17 of set 1 | cape town
# Processing record 18 of set 1 | le port
# Processing record 19 of set 1 | tuktoyaktuk
# Processing record 20 of set 1 | verkhoyansk
# Processing record 21 of set 1 | hassleholm
# Processing record 22 of set 1 | bredasdorp
# Processing record 23 of set 1 | belmonte
# Processing record 24 of set 1 | victoria
# Processing record 25 of set 1 | thompson
# Processing record 26 of set 1 | karakendzha
# City not found. Skipping...
# Processing record 27 of set 1 | skalnyy
# City not found. Skipping...
# Processing record 28 of set 1 | khatanga
# Processing record 29 of set 1 | kalmunai
# Processing record 30 of set 1 | kutum
# Processing record 31 of set 1 | east london
# Processing record 32 of set 1 | ponta do sol
# Processing record 33 of set 1 | tarauaca
# Processing record 34 of set 1 | puerto ayora
# Processing record 35 of set 1 | wasilla
# Processing record 36 of set 1 | baie-comeau
# Processing record 37 of set 1 | barrow
# Processing record 38 of set 1 | phan rang
# City not found. Skipping...
# Processing record 39 of set 1 | georgetown
# Processing record 40 of set 1 | gizo
# Processing record 41 of set 1 | saint-pierre
# Processing record 42 of set 1 | hilo
# Processing record 43 of set 1 | salinopolis
# Processing record 44 of set 1 | jiayuguan
# Processing record 45 of set 1 | arlit
# Processing record 46 of set 1 | hobart
# Processing record 47 of set 1 | faya
# Processing record 48 of set 1 | attawapiskat
# City not found. Skipping...
# Processing record 49 of set 1 | bengkulu
# Processing record 50 of set 1 | grand gaube
# Processing record 1 of set 2 | pevek
# Processing record 2 of set 2 | nicoya
# Processing record 3 of set 2 | yeppoon
# Processing record 4 of set 2 | castro
# Processing record 5 of set 2 | baruun-urt
# Processing record 6 of set 2 | fort saint john
# City not found. Skipping...
# Processing record 7 of set 2 | vaini
# Processing record 8 of set 2 | yambio
# Processing record 9 of set 2 | jamestown
# Processing record 10 of set 2 | havre-saint-pierre
# Processing record 11 of set 2 | leningradskiy
# Processing record 12 of set 2 | nkhotakota
# Processing record 13 of set 2 | taolanaro
# City not found. Skipping...
# Processing record 14 of set 2 | grindavik
# Processing record 15 of set 2 | toliary
# City not found. Skipping...
# Processing record 16 of set 2 | upernavik
# Processing record 17 of set 2 | fortuna
# Processing record 18 of set 2 | barawe
# City not found. Skipping...
# Processing record 19 of set 2 | talnakh
# Processing record 20 of set 2 | ourossogui
# Processing record 21 of set 2 | los llanos de aridane
# Processing record 22 of set 2 | barbar
# City not found. Skipping...
# Processing record 23 of set 2 | port elizabeth
# Processing record 24 of set 2 | cabedelo
# Processing record 25 of set 2 | aklavik
# Processing record 26 of set 2 | ornskoldsvik
# Processing record 27 of set 2 | babylon
# Processing record 28 of set 2 | coromandel
# Processing record 29 of set 2 | saleaula
# City not found. Skipping...
# Processing record 30 of set 2 | port lincoln
# Processing record 31 of set 2 | hornepayne
# Processing record 32 of set 2 | barentsburg
# City not found. Skipping...
# Processing record 33 of set 2 | lompoc
# Processing record 34 of set 2 | kodiak
# Processing record 35 of set 2 | cumaribo
# City not found. Skipping...
# Processing record 36 of set 2 | saskylakh
# Processing record 37 of set 2 | ribeira grande
# Processing record 38 of set 2 | malgrat de mar
# Processing record 39 of set 2 | bassila
# Processing record 40 of set 2 | abbeville
# Processing record 41 of set 2 | gimli
# Processing record 42 of set 2 | cervo
# Processing record 43 of set 2 | honiara
# Processing record 44 of set 2 | peniche
# Processing record 45 of set 2 | inhuma
# Processing record 46 of set 2 | saint anthony
# Processing record 47 of set 2 | florianopolis
# Processing record 48 of set 2 | port alfred
# Processing record 49 of set 2 | kamenskoye
# City not found. Skipping...
# Processing record 50 of set 2 | acapulco
# Processing record 1 of set 3 | mahebourg
# Processing record 2 of set 3 | liuhe
# Processing record 3 of set 3 | yellowknife
# Processing record 4 of set 3 | chapais
# Processing record 5 of set 3 | bluff
# Processing record 6 of set 3 | acarau
# Processing record 7 of set 3 | san cristobal
# Processing record 8 of set 3 | kavieng
# Processing record 9 of set 3 | zhanakorgan
# Processing record 10 of set 3 | hithadhoo
# Processing record 11 of set 3 | atuona
# Processing record 12 of set 3 | arman
# Processing record 13 of set 3 | haljala
# Processing record 14 of set 3 | binzhou
# Processing record 15 of set 3 | necochea
# Processing record 16 of set 3 | geraldton
# Processing record 17 of set 3 | luderitz
# Processing record 18 of set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing record 19 of set 3 | severo-kurilsk
# Processing record 20 of set 3 | erdaojiang
# Processing record 21 of set 3 | netivot
# Processing record 22 of set 3 | hobyo
# Processing record 23 of set 3 | busselton
# Processing record 24 of set 3 | maragogi
# Processing record 25 of set 3 | sitka
# Processing record 26 of set 3 | haines junction
# Processing record 27 of set 3 | mnogovershinnyy
# Processing record 28 of set 3 | pampa
# Processing record 29 of set 3 | petropavl
# Processing record 30 of set 3 | cayenne
# Processing record 31 of set 3 | namatanai
# Processing record 32 of set 3 | comodoro rivadavia
# Processing record 33 of set 3 | clyde river
# Processing record 34 of set 3 | mar del plata
# Processing record 35 of set 3 | tasiilaq
# Processing record 36 of set 3 | kribi
# Processing record 37 of set 3 | sorvag
# City not found. Skipping...
# Processing record 38 of set 3 | azimur
# City not found. Skipping...
# Processing record 39 of set 3 | yar-sale
# Processing record 40 of set 3 | port blair
# Processing record 41 of set 3 | poum
# Processing record 42 of set 3 | wyndham
# Processing record 43 of set 3 | umm durman
# City not found. Skipping...
# Processing record 44 of set 3 | mount gambier
# Processing record 45 of set 3 | nikolskoye
# Processing record 46 of set 3 | kuroiso
# Processing record 47 of set 3 | port macquarie
# Processing record 48 of set 3 | obo
# Processing record 49 of set 3 | juegang
# Processing record 50 of set 3 | zhukovka
# Processing record 1 of set 4 | kiunga
# Processing record 2 of set 4 | bambous virieux
# Processing record 3 of set 4 | raga
# Processing record 4 of set 4 | marzuq
# Processing record 5 of set 4 | kargil
# Processing record 6 of set 4 | avarua
# Processing record 7 of set 4 | lodwar
# Processing record 8 of set 4 | wanning
# Processing record 9 of set 4 | hasaki
# Processing record 10 of set 4 | alofi
# Processing record 11 of set 4 | lebu
# Processing record 12 of set 4 | eldorado
# Processing record 13 of set 4 | kyzyl-suu
# Processing record 14 of set 4 | palabuhanratu
# City not found. Skipping...
# Processing record 15 of set 4 | el dorado
# Processing record 16 of set 4 | viligili
# City not found. Skipping...
# Processing record 17 of set 4 | makungu
# Processing record 18 of set 4 | saint george
# Processing record 19 of set 4 | butaritari
# Processing record 20 of set 4 | norman wells
# Processing record 21 of set 4 | palauig
# Processing record 22 of set 4 | avera
# Processing record 23 of set 4 | chuy
# Processing record 24 of set 4 | provideniya
# Processing record 25 of set 4 | dikson
# Processing record 26 of set 4 | karangampel
# Processing record 27 of set 4 | katsuura
# Processing record 28 of set 4 | hami
# Processing record 29 of set 4 | juneau
# Processing record 30 of set 4 | camacha
# Processing record 31 of set 4 | kapaa
# Processing record 32 of set 4 | diu
# Processing record 33 of set 4 | klaksvik
# Processing record 34 of set 4 | ballina
# Processing record 35 of set 4 | grand river south east
# City not found. Skipping...
# Processing record 36 of set 4 | mbandaka
# Processing record 37 of set 4 | pisco
# Processing record 38 of set 4 | kijang
# Processing record 39 of set 4 | enid
# Processing record 40 of set 4 | marcona
# City not found. Skipping...
# Processing record 41 of set 4 | ketchikan
# Processing record 42 of set 4 | husavik
# Processing record 43 of set 4 | blythe
# Processing record 44 of set 4 | cabo san lucas
# Processing record 45 of set 4 | lorengau
# Processing record 46 of set 4 | yasothon
# Processing record 47 of set 4 | jining
# Processing record 48 of set 4 | dickinson
# Processing record 49 of set 4 | anori
# Processing record 50 of set 4 | waipawa
# Processing record 1 of set 5 | tateyama
# Processing record 2 of set 5 | omboue
# Processing record 3 of set 5 | sambava
# Processing record 4 of set 5 | gambela
# Processing record 5 of set 5 | gravelbourg
# Processing record 6 of set 5 | plettenberg bay
# Processing record 7 of set 5 | saint-philippe
# Processing record 8 of set 5 | port hardy
# Processing record 9 of set 5 | maddur
# Processing record 10 of set 5 | mangan
# Processing record 11 of set 5 | korla
# Processing record 12 of set 5 | bolungarvik
# City not found. Skipping...
# Processing record 13 of set 5 | amderma
# City not found. Skipping...
# Processing record 14 of set 5 | guerrero negro
# Processing record 15 of set 5 | tsihombe
# City not found. Skipping...
# Processing record 16 of set 5 | chokurdakh
# Processing record 17 of set 5 | prainha
# Processing record 18 of set 5 | corn island
# Processing record 19 of set 5 | meulaboh
# Processing record 20 of set 5 | kismayo
# Processing record 21 of set 5 | bethel
# Processing record 22 of set 5 | kristiinankaupunki
# Processing record 23 of set 5 | seoul
# Processing record 24 of set 5 | kodinsk
# Processing record 25 of set 5 | ewo
# Processing record 26 of set 5 | tuatapere
# Processing record 27 of set 5 | tsienyane
# City not found. Skipping...
# Processing record 28 of set 5 | asau
# Processing record 29 of set 5 | ngukurr
# City not found. Skipping...
# Processing record 30 of set 5 | swabi
# Processing record 31 of set 5 | plattsburgh
# Processing record 32 of set 5 | new norfolk
# Processing record 33 of set 5 | carnarvon
# Processing record 34 of set 5 | sucre
# Processing record 35 of set 5 | kresttsy
# Processing record 36 of set 5 | mezen
# Processing record 37 of set 5 | tlalchapa
# Processing record 38 of set 5 | aykhal
# Processing record 39 of set 5 | johnstown
# Processing record 40 of set 5 | anchorage
# Processing record 41 of set 5 | rocha
# Processing record 42 of set 5 | komsomolskiy
# Processing record 43 of set 5 | panormos
# Processing record 44 of set 5 | chulym
# Processing record 45 of set 5 | rosario
# Processing record 46 of set 5 | ancud
# Processing record 47 of set 5 | lambarene
# Processing record 48 of set 5 | daxian
# City not found. Skipping...
# Processing record 49 of set 5 | markivka
# Processing record 50 of set 5 | mundo nuevo
# Processing record 1 of set 6 | qaanaaq
# Processing record 2 of set 6 | maningrida
# Processing record 3 of set 6 | madaoua
# Processing record 4 of set 6 | college
# Processing record 5 of set 6 | macaboboni
# City not found. Skipping...
# Processing record 6 of set 6 | vardo
# Processing record 7 of set 6 | rungata
# City not found. Skipping...
# Processing record 8 of set 6 | temir
# Processing record 9 of set 6 | karacakoy
# Processing record 10 of set 6 | tobol
# Processing record 11 of set 6 | goderich
# Processing record 12 of set 6 | fairbanks
# Processing record 13 of set 6 | nautla
# Processing record 14 of set 6 | muzhi
# Processing record 15 of set 6 | vestmannaeyjar
# Processing record 16 of set 6 | altay
# Processing record 17 of set 6 | sao filipe
# Processing record 18 of set 6 | talara
# Processing record 19 of set 6 | nizhneyansk
# City not found. Skipping...
# Processing record 20 of set 6 | touros
# Processing record 21 of set 6 | ahipara
# Processing record 22 of set 6 | belushya guba
# City not found. Skipping...
# Processing record 23 of set 6 | ostrovnoy
# Processing record 24 of set 6 | lata
# Processing record 25 of set 6 | homer
# Processing record 26 of set 6 | umm lajj
# Processing record 27 of set 6 | lavrentiya
# Processing record 28 of set 6 | labrea
# Processing record 29 of set 6 | chato
# Processing record 30 of set 6 | anadyr
# Processing record 31 of set 6 | komsomolets
# Processing record 32 of set 6 | dunedin
# Processing record 33 of set 6 | presidencia roque saenz pena
# Processing record 34 of set 6 | ahuimanu
# Processing record 35 of set 6 | kautokeino
# Processing record 36 of set 6 | bani
# Processing record 37 of set 6 | nizhneudinsk
# Processing record 38 of set 6 | hambantota
# Processing record 39 of set 6 | bonavista
# Processing record 40 of set 6 | teahupoo
# Processing record 41 of set 6 | cayambe
# Processing record 42 of set 6 | le moule
# Processing record 43 of set 6 | blagoyevo
# Processing record 44 of set 6 | hwange
# Processing record 45 of set 6 | maketu
# Processing record 46 of set 6 | rodrigues alves
# Processing record 47 of set 6 | constitucion
# Processing record 48 of set 6 | makakilo city
# Processing record 49 of set 6 | black river
# Processing record 50 of set 6 | waddan
# Processing record 1 of set 7 | wagar
# Processing record 2 of set 7 | iranshahr
# Processing record 3 of set 7 | adrar
# Processing record 4 of set 7 | airai
# Processing record 5 of set 7 | bundibugyo
# Processing record 6 of set 7 | suzuka
# Processing record 7 of set 7 | samusu
# City not found. Skipping...
# Processing record 8 of set 7 | eskasem
# City not found. Skipping...
# Processing record 9 of set 7 | derzhavinsk
# Processing record 10 of set 7 | nago
# Processing record 11 of set 7 | bubaque
# Processing record 12 of set 7 | tiverton
# Processing record 13 of set 7 | boda
# Processing record 14 of set 7 | faanui
# Processing record 15 of set 7 | nelson bay
# Processing record 16 of set 7 | olga
# Processing record 17 of set 7 | meadow lake
# Processing record 18 of set 7 | pathein
# Processing record 19 of set 7 | kahului
# Processing record 20 of set 7 | magdagachi
# Processing record 21 of set 7 | torbay
# Processing record 22 of set 7 | laguna
# Processing record 23 of set 7 | inhambane
# Processing record 24 of set 7 | oistins
# Processing record 25 of set 7 | dwarka
# Processing record 26 of set 7 | aksha
# Processing record 27 of set 7 | nicolas bravo
# Processing record 28 of set 7 | srednekolymsk
# Processing record 29 of set 7 | oga
# Processing record 30 of set 7 | half moon bay
# Processing record 31 of set 7 | caravelas
# Processing record 32 of set 7 | matale
# Processing record 33 of set 7 | emba
# Processing record 34 of set 7 | sovetskiy
# Processing record 35 of set 7 | tual
# Processing record 36 of set 7 | viedma
# Processing record 37 of set 7 | malakal
# Processing record 38 of set 7 | porto walter
# Processing record 39 of set 7 | mackay
# Processing record 40 of set 7 | oktyabrskoye
# Processing record 41 of set 7 | aloleng
# Processing record 42 of set 7 | the pas
# Processing record 43 of set 7 | dandeli
# Processing record 44 of set 7 | ajaccio
# Processing record 45 of set 7 | pirgos
# Processing record 46 of set 7 | sorland
# Processing record 47 of set 7 | cabanas
# Processing record 48 of set 7 | vanimo
# Processing record 49 of set 7 | el faiyum
# City not found. Skipping...
# Processing record 50 of set 7 | kabanga
# Processing record 1 of set 8 | ayorou
# Processing record 2 of set 8 | barentu
# Processing record 3 of set 8 | santa maria del oro
# Processing record 4 of set 8 | pinega
# Processing record 5 of set 8 | aksarayskiy
# Processing record 6 of set 8 | pingliang
# Processing record 7 of set 8 | portland
# Processing record 8 of set 8 | sal rei
# Processing record 9 of set 8 | moron
# Processing record 10 of set 8 | samarai
# Processing record 11 of set 8 | okhotsk
# Processing record 12 of set 8 | abha
# Processing record 13 of set 8 | tahoua
# Processing record 14 of set 8 | karwar
# Processing record 15 of set 8 | lebanon
# Processing record 16 of set 8 | worland
# Processing record 17 of set 8 | ilam
# Processing record 18 of set 8 | nabire
# Processing record 19 of set 8 | sioux lookout
# Processing record 20 of set 8 | vao
# Processing record 21 of set 8 | port moresby
# Processing record 22 of set 8 | kant
# Processing record 23 of set 8 | flinders
# Processing record 24 of set 8 | saint quentin
# City not found. Skipping...
# Processing record 25 of set 8 | tiksi
# Processing record 26 of set 8 | saint-augustin
# Processing record 27 of set 8 | bismarck
# Processing record 28 of set 8 | mpongwe
# Processing record 29 of set 8 | dingle
# Processing record 30 of set 8 | siocon
# Processing record 31 of set 8 | anito
# Processing record 32 of set 8 | amga
# Processing record 33 of set 8 | vila velha
# Processing record 34 of set 8 | oytal
# Processing record 35 of set 8 | pangody
# Processing record 36 of set 8 | alice springs
# Processing record 37 of set 8 | banepa
# Processing record 38 of set 8 | oktyabrskiy
# Processing record 39 of set 8 | gurskoye
# City not found. Skipping...
# Processing record 40 of set 8 | koungou
# Processing record 41 of set 8 | cidreira
# Processing record 42 of set 8 | vieques
# Processing record 43 of set 8 | esperance
# Processing record 44 of set 8 | yandoon
# City not found. Skipping...
# Processing record 45 of set 8 | kirakira
# Processing record 46 of set 8 | yaan
# Processing record 47 of set 8 | warqla
# City not found. Skipping...
# Processing record 48 of set 8 | parkhill
# Processing record 49 of set 8 | erzin
# Processing record 50 of set 8 | sipe sipe
# Processing record 1 of set 9 | churapcha
# Processing record 2 of set 9 | buala
# Processing record 3 of set 9 | yagodnoye
# Processing record 4 of set 9 | phangnga
# Processing record 5 of set 9 | bollnas
# Processing record 6 of set 9 | tommot
# Processing record 7 of set 9 | mont-dore
# Processing record 8 of set 9 | chany
# Processing record 9 of set 9 | sisimiut
# Processing record 10 of set 9 | ngunguru
# Processing record 11 of set 9 | jacareacanga
# Processing record 12 of set 9 | aswan
# Processing record 13 of set 9 | calatayud
# Processing record 14 of set 9 | oranjestad
# Processing record 15 of set 9 | anagni
# Processing record 16 of set 9 | elizabeth city
# Processing record 17 of set 9 | jurm
# Processing record 18 of set 9 | griffith
# Processing record 19 of set 9 | kruisfontein
# Processing record 20 of set 9 | jaisalmer
# Processing record 21 of set 9 | megion
# Processing record 22 of set 9 | kuching
# Processing record 23 of set 9 | harer
# Processing record 24 of set 9 | hvammstangi
# City not found. Skipping...
# Processing record 25 of set 9 | asfi
# Processing record 26 of set 9 | san patricio
# Processing record 27 of set 9 | zomba
# Processing record 28 of set 9 | waingapu
# Processing record 29 of set 9 | cherskiy
# Processing record 30 of set 9 | lewistown
# Processing record 31 of set 9 | ndele
# Processing record 32 of set 9 | igrim
# Processing record 33 of set 9 | sumbe
# Processing record 34 of set 9 | asamankese
# Processing record 35 of set 9 | yerbogachen
# Processing record 36 of set 9 | egvekinot
# Processing record 37 of set 9 | hervey bay
# Processing record 38 of set 9 | hajnowka
# Processing record 39 of set 9 | paucartambo
# City not found. Skipping...
# Processing record 40 of set 9 | hamilton
# Processing record 41 of set 9 | mouzakion
# City not found. Skipping...
# Processing record 42 of set 9 | yining
# Processing record 43 of set 9 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing record 44 of set 9 | menongue
# Processing record 45 of set 9 | puerto del rosario
# Processing record 46 of set 9 | gobabis
# Processing record 47 of set 9 | shimoda
# Processing record 48 of set 9 | gordeyevka
# Processing record 49 of set 9 | bojnurd
# Processing record 50 of set 9 | kobelyaky
# Processing record 1 of set 10 | kiama
# Processing record 2 of set 10 | mus
# Processing record 3 of set 10 | shaunavon
# Processing record 4 of set 10 | zhirnovsk
# Processing record 5 of set 10 | hihifo
# City not found. Skipping...
# Processing record 6 of set 10 | lucea
# Processing record 7 of set 10 | itupiranga
# Processing record 8 of set 10 | bitkine
# Processing record 9 of set 10 | ukiah
# Processing record 10 of set 10 | smithers
# Processing record 11 of set 10 | antofagasta
# Processing record 12 of set 10 | urucara
# Processing record 13 of set 10 | nioro
# Processing record 14 of set 10 | urdzhar
# City not found. Skipping...
# Processing record 15 of set 10 | payo
# Processing record 16 of set 10 | athabasca
# Processing record 17 of set 10 | la ronge
# Processing record 18 of set 10 | broome
# Processing record 19 of set 10 | mys shmidta
# City not found. Skipping...
# Processing record 20 of set 10 | stillwater
# Processing record 21 of set 10 | sabang
# Processing record 22 of set 10 | mayor pablo lagerenza
# Processing record 23 of set 10 | brokopondo
# Processing record 24 of set 10 | conakry
# Processing record 25 of set 10 | gouyave
# Processing record 26 of set 10 | storforshei
# Processing record 27 of set 10 | lolua
# City not found. Skipping...
# Processing record 28 of set 10 | nueva gerona
# Processing record 29 of set 10 | narsaq
# Processing record 30 of set 10 | caimito
# Processing record 31 of set 10 | bjorkelangen
# Processing record 32 of set 10 | pinotepa nacional
# Processing record 33 of set 10 | ulverstone
# Processing record 34 of set 10 | arkhara
# Processing record 35 of set 10 | taburi
# City not found. Skipping...
# Processing record 36 of set 10 | la rioja
# Processing record 37 of set 10 | robertsport
# Processing record 38 of set 10 | ilulissat
# Processing record 39 of set 10 | vaitupu
# City not found. Skipping...
# Processing record 40 of set 10 | camapua
# Processing record 41 of set 10 | perth
# Processing record 42 of set 10 | bulgan
# Processing record 43 of set 10 | hofn
# Processing record 44 of set 10 | celestun
# Processing record 45 of set 10 | souillac
# Processing record 46 of set 10 | port hedland
# Processing record 47 of set 10 | kotdwara
# Processing record 48 of set 10 | senhor do bonfim
# Processing record 49 of set 10 | bilibino
# Processing record 50 of set 10 | beringovskiy
# Processing record 1 of set 11 | eston
# Processing record 2 of set 11 | mwinilunga
# Processing record 3 of set 11 | medeiros neto
# Processing record 4 of set 11 | yulara
# Processing record 5 of set 11 | coihaique
# Processing record 6 of set 11 | villa vazquez
# City not found. Skipping...
# Processing record 7 of set 11 | shubarkuduk
# Processing record 8 of set 11 | deer lake
# Processing record 9 of set 11 | boulsa
# Processing record 10 of set 11 | pangkalanbuun
# Processing record 11 of set 11 | mogadishu
# Processing record 12 of set 11 | isangel
# Processing record 13 of set 11 | bandar-e lengeh
# Processing record 14 of set 11 | codrington
# Processing record 15 of set 11 | namikupa
# Processing record 16 of set 11 | lakeside
# Processing record 17 of set 11 | kangaatsiaq
# Processing record 18 of set 11 | mount isa
# Processing record 19 of set 11 | along
# Processing record 20 of set 11 | port shepstone
# Processing record 21 of set 11 | daru
# Processing record 22 of set 11 | naze
# Processing record 23 of set 11 | lagoa
# Processing record 24 of set 11 | higuey
# City not found. Skipping...
# Processing record 25 of set 11 | camargo
# Processing record 26 of set 11 | piacabucu
# Processing record 27 of set 11 | zhetybay
# City not found. Skipping...
# Processing record 28 of set 11 | sao joao da barra
# Processing record 29 of set 11 | qasigiannguit
# Processing record 30 of set 11 | burnie
# Processing record 31 of set 11 | kieta
# Processing record 32 of set 11 | champerico
# Processing record 33 of set 11 | kloulklubed
# Processing record 34 of set 11 | pombas
# Processing record 35 of set 11 | kaz
# Processing record 36 of set 11 | salalah
# Processing record 37 of set 11 | viseu
# Processing record 38 of set 11 | birao
# Processing record 39 of set 11 | puerto rondon
# Processing record 40 of set 11 | wahran
# City not found. Skipping...
# Processing record 41 of set 11 | kibakwe
# Processing record 42 of set 11 | hualmay
# Processing record 43 of set 11 | grenfell
# Processing record 44 of set 11 | beloha
# Processing record 45 of set 11 | merauke
# Processing record 46 of set 11 | liku
# Processing record 47 of set 11 | robat karim
# Processing record 48 of set 11 | xam nua
# Processing record 49 of set 11 | camaqua
# Processing record 50 of set 11 | damghan
# Processing record 1 of set 12 | constantine
# Processing record 2 of set 12 | coahuayana
# Processing record 3 of set 12 | opobo
# City not found. Skipping...
# Processing record 4 of set 12 | port augusta
# Processing record 5 of set 12 | jackson
# Processing record 6 of set 12 | natchitoches
# Processing record 7 of set 12 | puerto penasco
# Processing record 8 of set 12 | whithorn
# Processing record 9 of set 12 | mugan
# Processing record 10 of set 12 | havelock
# Processing record 11 of set 12 | hay river
# Processing record 12 of set 12 | catamarca
# Processing record 13 of set 12 | port arthur
# Processing record 14 of set 12 | seydisehir
# Processing record 15 of set 12 | palora
# Processing record 16 of set 12 | hamza
# Processing record 17 of set 12 | olafsvik
# Processing record 18 of set 12 | waitati
# Processing record 19 of set 12 | amboise
# Processing record 20 of set 12 | taltal
# Processing record 21 of set 12 | bom jardim
# Processing record 22 of set 12 | yenangyaung
# Processing record 23 of set 12 | stromness
# Processing record 24 of set 12 | tutoia
# Processing record 25 of set 12 | tumannyy
# City not found. Skipping...
# Processing record 26 of set 12 | alegrete
# Processing record 27 of set 12 | darhan
# Processing record 28 of set 12 | den helder
# Processing record 29 of set 12 | coquimbo
# Processing record 30 of set 12 | kabelvag
# Processing record 31 of set 12 | zhigansk
# Processing record 32 of set 12 | south whittier
# Processing record 33 of set 12 | ulladulla
# Processing record 34 of set 12 | atasu
# Processing record 35 of set 12 | bamiantong
# Processing record 36 of set 12 | kuybyshevo
# Processing record 37 of set 12 | moses lake
# Processing record 38 of set 12 | godda
# Processing record 39 of set 12 | abnub
# Processing record 40 of set 12 | nuuk
# Processing record 41 of set 12 | chernihiv
# Processing record 42 of set 12 | kaa-khem
# Processing record 43 of set 12 | turan
# Processing record 44 of set 12 | ghanzi
# Processing record 45 of set 12 | natal
# Processing record 46 of set 12 | rio verde de mato grosso
# Processing record 47 of set 12 | cockburn town
# Processing record 48 of set 12 | sentyabrskiy
# City not found. Skipping...
# Processing record 49 of set 12 | dalnerechensk
# Processing record 50 of set 12 | gorontalo
# Processing record 1 of set 13 | caconda
# Processing record 2 of set 13 | santa cruz
# Processing record 3 of set 13 | utiel
# Processing record 4 of set 13 | octeville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 547

# %%
#Convert l-d to pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Longyearbyen  78.2186   15.6401     30.04        64          40
# 1          Ushuaia -54.8000  -68.3000     31.66        93          75
# 2  Arraial Do Cabo -22.9661  -42.0278     84.16        69           0
# 3         Hermanus -34.4187   19.2345     67.80        80          34
# 4       Kaitangata -46.2817  169.8464     43.99        92         100
# 5          Rikitea -23.1203 -134.9692     72.64        67          40
# 6      Zephyrhills  28.2336  -82.1812     86.72        64           1
# 7           Kamina  -8.7386   24.9906     82.83        25          15
# 8       Nanortalik  60.1432  -45.2371     40.55        75          14
# 9        Nantucket  41.2835  -70.0995     59.07        77          96
#
#    Wind Speed Country                 Date
# 0        9.22      SJ  2021-05-28 14:24:14
# 1       20.71      AR  2021-05-28 14:24:14
# 2       11.50      BR  2021-05-28 14:24:06
# 3       21.50      ZA  2021-05-28 14:24:15
# 4        3.58      NZ  2021-05-28 14:24:15
# 5       12.41      PF  2021-05-28 14:24:16
# 6        3.18      US  2021-05-28 14:24:16
# 7        4.05      CD  2021-05-28 14:20:21
# 8        6.93      GL  2021-05-28 14:24:17
# 9       19.26      US  2021-05-28 14:20:37

# %%
#Reorder cols
new_col_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0     Longyearbyen      SJ  2021-05-28 14:24:14  78.2186   15.6401     30.04
# 1          Ushuaia      AR  2021-05-28 14:24:14 -54.8000  -68.3000     31.66
# 2  Arraial Do Cabo      BR  2021-05-28 14:24:06 -22.9661  -42.0278     84.16
# 3         Hermanus      ZA  2021-05-28 14:24:15 -34.4187   19.2345     67.80
# 4       Kaitangata      NZ  2021-05-28 14:24:15 -46.2817  169.8464     43.99
# 5          Rikitea      PF  2021-05-28 14:24:16 -23.1203 -134.9692     72.64
# 6      Zephyrhills      US  2021-05-28 14:24:16  28.2336  -82.1812     86.72
# 7           Kamina      CD  2021-05-28 14:20:21  -8.7386   24.9906     82.83
# 8       Nanortalik      GL  2021-05-28 14:24:17  60.1432  -45.2371     40.55
# 9        Nantucket      US  2021-05-28 14:20:37  41.2835  -70.0995     59.07
#
#    Humidity  Cloudiness  Wind Speed
# 0        64          40        9.22
# 1        93          75       20.71
# 2        69           0       11.50
# 3        80          34       21.50
# 4        92         100        3.58
# 5        67          40       12.41
# 6        64           1        3.18
# 7        25          15        4.05
# 8        75          14        6.93
# 9        77          96       19.26

# %%
#Create output file path
output_path = "Weather_Database/cities.csv"

#Export city_data
city_data_df.to_csv(output_path, index_label = "City_ID")
